# %%
import celltest
import logging
from IPython.core.formatters import DisplayFormatter
import os

# %%
from celltest.cells import CellConvert
from celltest.utils import (_tokenize, fully_dedent, save_outputs)

# %%
from celltest.utils import parse_params

# %%
parse_params(["test_param", "comment", "ssdfsdfsd dfsdf ", "ignore"],["ignore", "ignore_outputs"])
# Out:
# ERROR:celltest:Ignoring unknown param test_param
# {'comment': 'ssdfsdfsd dfsdf ', 'ignore': True}

# %%
# CT: 
d = DisplayFormatter()
d.format([x for x in _tokenize('''{'a'}
['a']''')], include="text/plain")[0]['text/plain']
# Out:
# '[TokenInfo(type=54 (OP), string=\'{\', start=(1, 0), end=(1, 1), line="{\'a\'}\\n"),\n TokenInfo(type=3 (STRING), string="\'a\'", start=(1, 1), end=(1, 4), line="{\'a\'}\\n"),\n TokenInfo(type=54 (OP), string=\'}\', start=(1, 4), end=(1, 5), line="{\'a\'}\\n"),\n TokenInfo(type=4 (NEWLINE), string=\'\\n\', start=(1, 5), end=(1, 6), line="{\'a\'}\\n"),\n TokenInfo(type=54 (OP), string=\'[\', start=(2, 0), end=(2, 1), line="[\'a\']"),\n TokenInfo(type=3 (STRING), string="\'a\'", start=(2, 1), end=(2, 4), line="[\'a\']"),\n TokenInfo(type=54 (OP), string=\']\', start=(2, 4), end=(2, 5), line="[\'a\']"),\n TokenInfo(type=4 (NEWLINE), string=\'\', start=(2, 5), end=(2, 6), line=\'\'),\n TokenInfo(type=0 (ENDMARKER), string=\'\', start=(3, 0), end=(3, 0), line=\'\')]'

# %%
# CT: setup
if os.path.exists(os.path.join(os.getcwd(),'tests')):
    cellconvert = CellConvert(filepath='tests/example.ipynb')
else:
    cellconvert = CellConvert(filepath='example.ipynb')

# %%
cellconvert.code_d_
# Out:
# {1: '# CT: ignore_outputs\nimport pandas as pd\nimport tokenize, \\\nio\nimport os\nimport logging',
#  3: '# CT: ignore, some_giberish\nos.path.join?',
#  4: '# CT: setup\ndf = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")',
#  5: 'logging.error("test")\nlogging.error("test")\nprint("test")\nlogging.error("test")\nprint("test")',
#  6: '# CT: param1, param2; param3\nprint("Hello World")\nprint("Hello World")\nlogging.error("test")\nlogging.error("test")\nprint("test")\nlogging.error("test")',
#  7: 'print("Hello World")',
#  8: 'df.head(5)',
#  9: 'df.shape',
#  10: '# CT: ignore_outputs\ndf.describe()',
#  11: 'df.drop("location_1", axis=1).describe(include="all")',
#  12: 'df.dtypes',
#  13: '# CT: almost_equal\ndf.bachelor_s_degree_or_higher.mean()',
#  14: 'df.geography.count()',
#  15: 'df.geography_type.unique()',
#  16: 'df.less_than_high_school_graduate.value_counts()',
#  18: '"a   ...  b".split(" ")',
#  19: '"" is \'\'',
#  20: '" "*4',
#  21: 'None',
# ...

# %%
cellconvert.metadata_d
# Out:
# {3: ['ignore'], 4: ['setup'], 5: ['setup'], 7: ['ignore_output']}

# %%
cellconvert.remove_backslash()
# Out:
# {1: '# CT: ignore_outputs\nimport pandas as pd\nimport tokenize,  io\nimport os\nimport logging',
#  3: '# CT: ignore, some_giberish\nos.path.join?',
#  4: '# CT: setup\ndf = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")',
#  5: 'logging.error("test")\nlogging.error("test")\nprint("test")\nlogging.error("test")\nprint("test")',
#  6: '# CT: param1, param2; param3\nprint("Hello World")\nprint("Hello World")\nlogging.error("test")\nlogging.error("test")\nprint("test")\nlogging.error("test")',
#  7: 'print("Hello World")',
#  8: 'df.head(5)',
#  9: 'df.shape',
#  10: '# CT: ignore_outputs\ndf.describe()',
#  11: 'df.drop("location_1", axis=1).describe(include="all")',
#  12: 'df.dtypes',
#  13: '# CT: almost_equal\ndf.bachelor_s_degree_or_higher.mean()',
#  14: 'df.geography.count()',
#  15: 'df.geography_type.unique()',
#  16: 'df.less_than_high_school_graduate.value_counts()',
#  18: '"a   ...  b".split(" ")',
#  19: '"" is \'\'',
#  20: '" "*4',
#  21: 'None',
# ...

# %%
cellconvert.carve_magic()
# Out:
# ({},
#  {1: '# CT: ignore_outputs\nimport pandas as pd\nimport tokenize,  io\nimport os\nimport logging',
#   3: '# CT: ignore, some_giberish\nos.path.join?',
#   4: '# CT: setup\ndf = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")',
#   5: 'logging.error("test")\nlogging.error("test")\nprint("test")\nlogging.error("test")\nprint("test")',
#   6: '# CT: param1, param2; param3\nprint("Hello World")\nprint("Hello World")\nlogging.error("test")\nlogging.error("test")\nprint("test")\nlogging.error("test")',
#   7: 'print("Hello World")',
#   8: 'df.head(5)',
#   9: 'df.shape',
#   10: '# CT: ignore_outputs\ndf.describe()',
#   11: 'df.drop("location_1", axis=1).describe(include="all")',
#   12: 'df.dtypes',
#   13: '# CT: almost_equal\ndf.bachelor_s_degree_or_higher.mean()',
#   14: 'df.geography.count()',
#   15: 'df.geography_type.unique()',
#   16: 'df.less_than_high_school_graduate.value_counts()',
#   18: '"a   ...  b".split(" ")',
#   19: '"" is \'\'',
# ...

# %%
cellconvert.carve_control_params()
# Out:
# ERROR:celltest:Ignoring unknown param ignore_output
# ERROR:celltest:Ignoring unknown param ignore,
# ERROR:celltest:Ignoring unknown param some_giberish
# ERROR:celltest:Ignoring unknown param param1,
# ERROR:celltest:Ignoring unknown param param2;
# ERROR:celltest:Ignoring unknown param param3
# ERROR:celltest:Ignoring unknown param almost_equal
# defaultdict(dict,
#             {'head_level': {'insert_saved_outputs': True},
#              3: {'ignore': True},
#              4: {'setup': True},
#              5: {'setup': True},
#              7: {},
#              1: {'ignore_outputs': True},
#              6: {},
#              8: {},
#              9: {},
#              10: {'ignore_outputs': True},
#              11: {},
#              12: {},
#              13: {},
#              14: {},
#              15: {},
#              16: {},
#              18: {},
#              19: {},
#              20: {},
#              21: {},
#              22: {},
#              23: {}})

# %%
cellconvert.carve_imports()
# Out:
# ('import pandas as pd \nimport tokenize ,io \nimport os \nimport logging \n',
#  {1: '',
#   4: 'df =pd .read_json ("https://data.smcgov.org/resource/mb6a-xn89.json")',
#   5: 'logging .error ("test")\nlogging .error ("test")\nprint ("test")\nlogging .error ("test")\nprint ("test")',
#   6: 'print ("Hello World")\nprint ("Hello World")\nlogging .error ("test")\nlogging .error ("test")\nprint ("test")\nlogging .error ("test")',
#   7: 'print ("Hello World")',
#   8: 'df .head (5 )',
#   9: 'df .shape ',
#   10: 'df .describe ()',
#   11: 'df .drop ("location_1",axis =1 ).describe (include ="all")',
#   12: 'df .dtypes ',
#   13: 'df .bachelor_s_degree_or_higher .mean ()',
#   14: 'df .geography .count ()',
#   15: 'df .geography_type .unique ()',
#   16: 'df .less_than_high_school_graduate .value_counts ()',
#   18: '"a   ...  b".split (" ")',
#   19: '""is \'\'',
#   20: '" "*4 ',
#   21: 'None ',
#   22: 'str (True )',
#   23: "'''True'''==str (True )"})

# %%
cellconvert.carve_setup()
# Out:
# ('df =pd .read_json ("https://data.smcgov.org/resource/mb6a-xn89.json")\nlogging .error ("test")\nlogging .error ("test")\nprint ("test")\nlogging .error ("test")\nprint ("test")',
#  {1: '',
#   6: 'print ("Hello World")\nprint ("Hello World")\nlogging .error ("test")\nlogging .error ("test")\nprint ("test")\nlogging .error ("test")',
#   7: 'print ("Hello World")',
#   8: 'df .head (5 )',
#   9: 'df .shape ',
#   10: 'df .describe ()',
#   11: 'df .drop ("location_1",axis =1 ).describe (include ="all")',
#   12: 'df .dtypes ',
#   13: 'df .bachelor_s_degree_or_higher .mean ()',
#   14: 'df .geography .count ()',
#   15: 'df .geography_type .unique ()',
#   16: 'df .less_than_high_school_graduate .value_counts ()',
#   18: '"a   ...  b".split (" ")',
#   19: '""is \'\'',
#   20: '" "*4 ',
#   21: 'None ',
#   22: 'str (True )',
#   23: "'''True'''==str (True )"})

# %%
from celltest.utils import indent
indent("""
    import pandas
    test = Dataframe()
    for i in range(10):
        i +=1
""")
# Out:
# '\n        import pandas \n        test =Dataframe ()\n        for i in range (10 ):\n            i +=1 \n'

# %%
# CT: setup
test = '''\
        return0()
        if (
            '2'
            ):
            True
        if True:
            1
            m
        else:
            3
        pdb.debug()    
        a = 3
        m
        # some comment

'''
test2 = '''

        return0()
        a = 2
        if ('2'):
            True
        if True:
            1
        else:
            3
        m

'''
test3 = '''
df. head()
'''
from tokenize import untokenize

untokenize([(x[0],x[1]) for x in _tokenize(test)])
# Out:
# "return0 ()\n        if (\n        '2'\n        ):\n            True \n        if True :\n            1 \n            m \n        else :\n            3 \n        pdb .debug ()\n        a =3 \n        m \n        # some comment\n\n"

# %%
fully_dedent(test)
# Out:
# "return0 ()\n        if (\n        '2'\n        ):\n            True \n        if True :\n            1 \n            m \n        else :\n            3 \n        pdb .debug ()\n        a =3 \n        m \n        # some comment\n\n"

# %%
[x for x in _tokenize(fully_dedent(test))]
# Out:
# [TokenInfo(type=1 (NAME), string='return0', start=(1, 0), end=(1, 7), line='return0 ()\n'),
#  TokenInfo(type=54 (OP), string='(', start=(1, 8), end=(1, 9), line='return0 ()\n'),
#  TokenInfo(type=54 (OP), string=')', start=(1, 9), end=(1, 10), line='return0 ()\n'),
#  TokenInfo(type=4 (NEWLINE), string='\n', start=(1, 10), end=(1, 11), line='return0 ()\n'),
#  TokenInfo(type=5 (INDENT), string='        ', start=(2, 0), end=(2, 8), line='        if (\n'),
#  TokenInfo(type=1 (NAME), string='if', start=(2, 8), end=(2, 10), line='        if (\n'),
#  TokenInfo(type=54 (OP), string='(', start=(2, 11), end=(2, 12), line='        if (\n'),
#  TokenInfo(type=61 (NL), string='\n', start=(2, 12), end=(2, 13), line='        if (\n'),
#  TokenInfo(type=3 (STRING), string="'2'", start=(3, 8), end=(3, 11), line="        '2'\n"),
#  TokenInfo(type=61 (NL), string='\n', start=(3, 11), end=(3, 12), line="        '2'\n"),
# ...

# %%
print(save_outputs(test3))
# Out:
# ct_cell_outputs['display_data'] =df .head ()

# %%
print(save_outputs(test2))
# Out:
# return0 ()
# a =2
# if ('2'):
#     True
# if True :
#     1
# else :
#     3
# ct_cell_outputs['display_data'] =m

# %%
print(cellconvert.make_tests(update=False, ))
# Out:
# """Tests automatically generated from notebook example.ipynb.
#
# Do not make direct changes in this file as it may be
# regenerated, make all changes in the notebook.
#
# Accepted parameters in notebook cells to control test flow:
# ['comment', 'setup', 'ignore_outputs', 'ignore_stderr', 'ignore_stdout', 'ignore', 'ignore_display_data', 'run_all_till_now']
#
# Accepted callbacks (if installed) to prettify the .py test file:
# black, yapf, isort
#
# To change the test file default copy and change the template.py from
# celltest/src/celltest.
# """
# from collections import defaultdict
# import io
# import logging
# from contextlib import redirect_stdout, redirect_stderr
# from unittest import TestCase, main
# import pandas as pd
# import tokenize ,io
# import os
# import logging
#
#
# import re
# from collections import defaultdict
# import logging
# import json
# from IPython .core .formatters import DisplayFormatter
#
#
# def escape_ansi (line ):
# ...

# %%
print(cellconvert.make_tests( callbacks=["black", "yapf"], update=False, insert_saved_outputs=True))
# Out:
# """Tests automatically generated from notebook example.ipynb.
#
# Do not make direct changes in this file as it may be
# regenerated, make all changes in the notebook.
#
# Accepted parameters in notebook cells to control test flow:
# ['comment', 'setup', 'ignore_outputs', 'ignore_stderr', 'ignore_stdout', 'ignore', 'ignore_display_data', 'run_all_till_now']
#
# Accepted callbacks (if installed) to prettify the .py test file:
# black, yapf, isort
#
# To change the test file default copy and change the template.py from
# celltest/src/celltest.
# """
# from collections import defaultdict
# import io
# import logging
# from contextlib import redirect_stdout, redirect_stderr
# from unittest import TestCase, main
# import pandas as pd
# import tokenize, io
# import os
# import logging
#
# import re
# from collections import defaultdict
# import logging
# import json
# from IPython.core.formatters import DisplayFormatter
#
#
# def escape_ansi(line):
# ...

# %%
# CT: comment "Just test assert"
assert 1 == 1

# %%
# CT: ignore
# convert current notebook to unittest
CellConvert(callbacks=['isort', 'black', 'yapf']).run()
