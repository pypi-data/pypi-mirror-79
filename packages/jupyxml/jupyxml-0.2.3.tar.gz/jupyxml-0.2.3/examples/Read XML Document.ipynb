# %%
from jupyxml import JupyXML

# %%
JupyXML("../cd_catalog.xml")
# Out:
# v0002 False
#             <div class="jupyxml">
#                 <style scoped>
#                     .card {
#     border: 1px solid #ccc;
#     padding: 8pt;
#     margin: 4pt 4pt 4pt 8pt
# }
#
# .level_even {
#     background-color: #f6f6f6;
# }
#
#
# .level_odd {
#     background-color: #ffffff;
# }
#
# .card-header {
#     font-size: 1.3em;
# }
#
# .card-body {
#     padding-left: 8pt;
# }
#
# .leaf_node {
#     border: 1px solid #ccc;
#     padding: 8pt;
#     margin-top: 4pt;
# }
#
# button.btn{
#     border: 1px solid #ccc;
#     background-color: white;
# }
#
# .card h3.jupyxml {
#     margin: 1pt;
# }
#                 </style>
#
# <div class="card level_even">
#     <div class="card-header" id="heading_1600394377094475">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1600394377094475"
#             aria-expanded="true" aria-controls="collapse_1600394377094475">
#           <h3 class="jupyxml">
#               Item: CATALOG
# ...
