# %% [markdown]
# # JupyXML
# ![logo](../jupyxml_logo.png)
#
# JupyXML is a small library designed to allow you to easily read an XML file and display it in Jupyter Notebooks.
#
# If you've ever used pandas in Jupyter Notebooks, like how it prints out a nice HTML table, but have to work with an XML file, this project is for you!
#
#
#
# The scope of this project is to:
# - Read an XML file with `lxml`
# - Display the XMl file as HTML with collapse options
# - Use an interactive widget to search/filter the nodes based on some criteria.

# %%
import jupyxml

# %%
print(f"Currently installed JupyXML version: {jupyxml.__version__}")
# Out:
# Currently installed JupyXML version: 0.2.1

# %%
from jupyxml import JupyXML

# %% [markdown]
# You can pass the XML file in as a string:

# %%
JupyXML("<b>Hello world, <i>I'm here to save you</i></b>")
# Out:
#             <style>
#
#
# .card {
#     border: 1px solid black;
#     box-shadow: grey 2px 2px;
#     padding: 8pt;
#     margin: 4pt 4pt 4pt 8pt
# }
#
# .card-header{
#     font-size: 1.3em;
# }
#
# .card-body{
#     padding-left: 8pt;
# }
#
# .leaf_node{
#     border: 1px solid grey;
#     padding: 8pt;
# }
#             </style>
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084769813">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084769813"
#             aria-expanded="true" aria-controls="collapse_1599487084769813">
#           <h3>
#               Item: b
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084769813" class="collapse False" aria-labelledby="heading_1599487084769813" >
#       <div class="card-body">
#         Text: Hello world,
# <div class="leaf_node">
#     <h3>Item: i</h3>
#     Text: I'm here to save you
# </div>
#
#       </div>
#     </div>
# </div>

# %% [markdown]
# You can also pass a filename:

# %%
# Grab this file from https://www.w3schools.com/xml/cd_catalog.xml
JupyXML("../cd_catalog.xml")
# Out:
#             <style>
#
#
# .card {
#     border: 1px solid black;
#     box-shadow: grey 2px 2px;
#     padding: 8pt;
#     margin: 4pt 4pt 4pt 8pt
# }
#
# .card-header{
#     font-size: 1.3em;
# }
#
# .card-body{
#     padding-left: 8pt;
# }
#
# .leaf_node{
#     border: 1px solid grey;
#     padding: 8pt;
# }
#             </style>
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224"
#             aria-expanded="true" aria-controls="collapse_1599487084775224">
#           <h3>
#               Item: CATALOG
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224" class="collapse False" aria-labelledby="heading_1599487084775224" >
#       <div class="card-body">
#         Text:
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_0">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_0"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_0">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_0" class="collapse True" aria-labelledby="heading_1599487084775224_0" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: Empire Burlesque
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Bob Dylan
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: USA
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: Columbia
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 10.90
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1985
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_1">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_1"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_1">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_1" class="collapse False" aria-labelledby="heading_1599487084775224_1" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: Hide your heart
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Bonnie Tyler
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: UK
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: CBS Records
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 9.90
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1988
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_2">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_2"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_2">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_2" class="collapse False" aria-labelledby="heading_1599487084775224_2" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: Greatest Hits
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Dolly Parton
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: USA
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: RCA
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 9.90
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1982
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_3">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_3"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_3">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_3" class="collapse False" aria-labelledby="heading_1599487084775224_3" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: Still got the blues
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Gary Moore
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: UK
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: Virgin records
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 10.20
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1990
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_4">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_4"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_4">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_4" class="collapse False" aria-labelledby="heading_1599487084775224_4" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: Eros
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Eros Ramazzotti
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: EU
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: BMG
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 9.90
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1997
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_5">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_5"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_5">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_5" class="collapse False" aria-labelledby="heading_1599487084775224_5" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: One night only
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Bee Gees
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: UK
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: Polydor
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 10.90
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1998
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_6">
#         <button class="btn btn-link" data-toggle="collapse" data-target="#collapse_1599487084775224_6"
#             aria-expanded="true" aria-controls="collapse_1599487084775224_6">
#           <h3>
#               Item: CD
#           </h3>
#         </button>
#     </div>
#
#     <div id="collapse_1599487084775224_6" class="collapse False" aria-labelledby="heading_1599487084775224_6" >
#       <div class="card-body">
#         Text:
#
# <div class="leaf_node">
#     <h3>Item: TITLE</h3>
#     Text: Sylvias Mother
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: ARTIST</h3>
#     Text: Dr.Hook
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COUNTRY</h3>
#     Text: UK
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: COMPANY</h3>
#     Text: CBS
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: PRICE</h3>
#     Text: 8.10
# </div>
#
#
# <div class="leaf_node">
#     <h3>Item: YEAR</h3>
#     Text: 1973
# </div>
#
#       </div>
#     </div>
# </div>
#
#
# <div class="card">
#     <div class="card-header" id="heading_1599487084775224_7">
#         <button class="btn btn-link" data-toggle="colla
